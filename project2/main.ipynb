# %% [markdown]
# # Youth Tobacco Usage, India - Data Analysis

# %% [markdown]
# ### Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading dataset into file

# %%
df = pd.read_csv('datafile.csv')

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# #### head for initial idea about the dataset

# %%
df
# Out:
#                         State/UT   Area  Ever tobacco users (%)  \
# 0                          India  Total                    18.1
# 1                          India  Urban                    13.5
# 2                          India  Rural                    19.5
# 3    Andaman and Nicobar Islands  Total                    21.5
# 4    Andaman and Nicobar Islands  Urban                    13.3
# ..                           ...    ...                     ...
# 102                  Uttarakhand  Total                    31.4
# 103                  Uttarakhand  Urban                    39.5
# 104                  Uttarakhand  Rural                    28.2
# 105                  West Bengal  Total                    17.3
# 106                  West Bengal  Urban                    18.0
#
#      Current tobacco users (%)  Ever tobacco smokers (%)  \
# 0                          8.5                      11.0
# 1                          5.5                       8.1
# ...

# %% [markdown]
# #### info / describe for a basic statistics of the data

# %%
print('\n\tDataFrame description:\n')
df.describe()
# Out:
# 	DataFrame description:
#        Ever tobacco users (%)  Current tobacco users (%)  \
# count              107.000000                 107.000000
# mean                22.766355                  11.361682
# std                 19.375305                  14.912852
# min                  0.100000                   0.000000
# 25%                 10.700000                   3.250000
# 50%                 15.300000                   5.500000
# 75%                 26.300000                   8.550000
# max                 91.100000                  69.200000
#
#        Ever tobacco smokers (%)  Current tobacco smokers (%)  \
# count                107.000000                   107.000000
# mean                  14.852336                     9.095327
# std                   17.127818                    12.168366
# min                    0.100000                     0.000000
# 25%                    5.700000                     2.500000
# ...

# %% [markdown]
# #### Checking for null values using isnull

# %%
print('\n\tMissing Values Check:\n')
df_with_nulls = df[df.isnull().any(axis=1)]
df_with_nulls
# Out:
# 	Missing Values Check:
# Empty DataFrame
# ...

# %%
states_df=df[['State/UT','Area']]
states_df
# Out:
#                         State/UT   Area
# 0                          India  Total
# 1                          India  Urban
# 2                          India  Rural
# 3    Andaman and Nicobar Islands  Total
# 4    Andaman and Nicobar Islands  Urban
# ..                           ...    ...
# 102                  Uttarakhand  Total
# 103                  Uttarakhand  Urban
# 104                  Uttarakhand  Rural
# 105                  West Bengal  Total
# 106                  West Bengal  Urban
#
# [107 rows x 2 columns]

# %%
area_counts_df = states_df.groupby(['State/UT']).count()
area_counts_df
# Out:
#                              Area
# State/UT
# Andaman and Nicobar Islands     3
# Andhra Pradesh                  3
# Arunachal Pradesh               3
# Assam                           3
# Bihar                           3
# Chandigarh                      3
# Chhattisgarh                    3
# Dadra and Nagar Haweli          3
# Daman and Diu                   3
# Delhi                           3
# Goa                             3
# Gujarat                         3
# Haryana                         3
# Himachal Pradesh                3
# India                           3
# Jharkhand                       3
# Karnataka                       3
# Kerala                          3
# Lakshadweep                     3
# Madhya Pradesh                  3
# Maharashtra                     3
# Manipur                         3
# Meghalaya                       3
# Mizoram                         3
# Nagaland                        3
# Odisha                          3
# ...

# %% [markdown]
#     In the above DataFrame we could see that the 'West Bengal' State is missing a Area value and can be inspected further to add data or remove the entire row(s).

# %%
west_bengal_data = df[df['State/UT'] == 'West Bengal']
west_bengal_data
# Out:
#         State/UT   Area  Ever tobacco users (%)  Current tobacco users (%)  \
# 105  West Bengal  Total                    17.3                        7.1
# 106  West Bengal  Urban                    18.0                        6.9
#
#      Ever tobacco smokers (%)  Current tobacco smokers (%)  \
# 105                       9.3                          5.2
# 106                       9.1                          4.1
#
#      Ever cigarette users (%)  Current cigarette users (%)  \
# 105                       5.4                          3.6
# 106                       5.0                          2.2
#
#      Ever bidi users (%)   Current bidi users (%)  ...  \
# 105                   5.5                     2.9  ...
# 106                   2.9                     1.4  ...
#
#      Students who noticed cigarette advertisements/promotions at point of sale in past 30 days (%)  \
# 105                                               21.0
# ...

# %% [markdown]
# Here we can see that the entire rural row is missing from the data and we can choose to either remove 'West Bengal' or add a row with area as'Rural' and fill other data from a respected source, wherever we need both Rural and Urban areas for comparison of data.
#
# For now, I am dropping the state 'West Bengal' from the data, assuming that this is the only data we are able to work with and additional data on 'West Bengal / Rural' couldn't be found anywhere.

# %%
all_areas_df = df[df['State/UT'] != 'West Bengal']
all_areas_df
# Out:
#                         State/UT   Area  Ever tobacco users (%)  \
# 0                          India  Total                    18.1
# 1                          India  Urban                    13.5
# 2                          India  Rural                    19.5
# 3    Andaman and Nicobar Islands  Total                    21.5
# 4    Andaman and Nicobar Islands  Urban                    13.3
# ..                           ...    ...                     ...
# 100                Uttar Pradesh  Urban                     6.6
# 101                Uttar Pradesh  Rural                    36.3
# 102                  Uttarakhand  Total                    31.4
# 103                  Uttarakhand  Urban                    39.5
# 104                  Uttarakhand  Rural                    28.2
#
#      Current tobacco users (%)  Ever tobacco smokers (%)  \
# 0                          8.5                      11.0
# 1                          5.5                       8.1
# ...

# %% [markdown]
# ## Trend Analysis of Tobacco Usage "Rural" vs "Urban"

# %% [markdown]
# ### Separating into a smaller DataFrame

# %%
data = all_areas_df[['State/UT','Area','Ever tobacco users (%)','Current tobacco users (%)' ]]
data
# Out:
#                         State/UT   Area  Ever tobacco users (%)  \
# 0                          India  Total                    18.1
# 1                          India  Urban                    13.5
# 2                          India  Rural                    19.5
# 3    Andaman and Nicobar Islands  Total                    21.5
# 4    Andaman and Nicobar Islands  Urban                    13.3
# ..                           ...    ...                     ...
# 100                Uttar Pradesh  Urban                     6.6
# 101                Uttar Pradesh  Rural                    36.3
# 102                  Uttarakhand  Total                    31.4
# 103                  Uttarakhand  Urban                    39.5
# 104                  Uttarakhand  Rural                    28.2
#
#      Current tobacco users (%)
# 0                          8.5
# 1                          5.5
# 2                          9.4
# 3                          4.4
# 4                          3.4
# ...

# %% [markdown]
# #### Plotting the data

# %%
sns.barplot(x='State/UT', y='Ever tobacco users (%)', hue='Area', data=data)
plt.xticks(rotation = 90)
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(25, 12))

# Second plot (scatter plot + linear regression line)
sns.regplot(x='Ever tobacco users (%)', y='Current tobacco users (%)', data=data, ax=axs[0])
# Second plot (scatter plot + Polynomial regression line)
sns.regplot(x='Ever tobacco users (%)', y='Current tobacco users (%)', data=data, order=2, ax=axs[1])

axs[0].tick_params(axis='x', rotation=90)  # Rotate x-axis labels for readability
axs[1].tick_params(axis='x', rotation=90)  # Rotate x-axis labels for readability

plt.show()

# %%
fig, ax = plt.subplots()
df.plot(kind='hexbin', x='Ever tobacco users (%)', y='Current tobacco users (%)', gridsize=25, cmap='viridis', ax=ax)
ax.set_facecolor('black')
plt.show()

# %% [markdown]
# ## Interpretations from the above plots
